# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ([Link to broadcasting docs](https://docs.scipy.org/doc/numpy-1.15.0/user/basics.broadcasting.html))

# %% [markdown]
# # What is broadcasting?
#
# - An easy way to handle arithmetic between vectors
#
# ### Example
#
# - Let's say we have three different starting values: [1,2,3]
#     - Let's say we also have four different multipliers: [0.5, 0.75, 1.0, 1.25]
#
# - If we want to know the value for each starting value and each multiplier, we could loop through them:

# %%
for starting_value in [1,2,3]:
    for multiplier in [0.5,0.75,1,1.25]:
        value = starting_value*multiplier
        print('Starting value = {}; Multiplier = {}; Value = {}'.format(starting_value, multiplier, value))
# Out:
# Starting value = 1; Multiplier = 0.5; Value = 0.5
# Starting value = 1; Multiplier = 0.75; Value = 0.75
# Starting value = 1; Multiplier = 1; Value = 1
# Starting value = 1; Multiplier = 1.25; Value = 1.25
# Starting value = 2; Multiplier = 0.5; Value = 1.0
# Starting value = 2; Multiplier = 0.75; Value = 1.5
# Starting value = 2; Multiplier = 1; Value = 2
# Starting value = 2; Multiplier = 1.25; Value = 2.5
# Starting value = 3; Multiplier = 0.5; Value = 1.5
# Starting value = 3; Multiplier = 0.75; Value = 2.25
# Starting value = 3; Multiplier = 1; Value = 3
# Starting value = 3; Multiplier = 1.25; Value = 3.75

# %% [markdown]
# - If we wanted to calculate these values using matrix multiplication, we could use:
#
# $$
# \begin{bmatrix}1\\ 2\\ 3\end{bmatrix} \begin{bmatrix}0.5 & 0.75 & 1.0 & 1.25\end{bmatrix} = \begin{bmatrix}0.5 & 0.75 & 1.0 & 1.25\\ 1.0 & 1.5 & 2 & 2.5\\ 1.5 & 2.25 & 3.0 & 3.75\end{bmatrix}
# $$

# %% [markdown]
# - To do this with numpy, we can do it as:

# %%
array_starting_values = np.array([[1],[2],[3]])
array_multipliers = np.array([[0.5, 0.75, 1, 1.25]])
array_starting_values * array_multipliers
# Out:
# array([[0.5 , 0.75, 1.  , 1.25],
#        [1.  , 1.5 , 2.  , 2.5 ],
#        [1.5 , 2.25, 3.  , 3.75]])

# %% [markdown]
# - **Recall**: in linear algebra, in order to multiply two matrices, A and B, the number of columns in A must equal the number of rows in B. Thus, if A is an m x n matrix and B is an r x s matrix, n = r.
#     - If we look at the shapes of our arrays, we can see that this condition is satisfied

# %%
array_starting_values.shape, array_multipliers.shape
# Out:
# ((3, 1), (1, 4))

# %% [markdown]
# - *But what if we flipped the order?*

# %%
array_multipliers*array_starting_values
# Out:
# array([[0.5 , 0.75, 1.  , 1.25],
#        [1.  , 1.5 , 2.  , 2.5 ],
#        [1.5 , 2.25, 3.  , 3.75]])

# %% [markdown]
# - It still works
#     - All we need is for the two arrays to be compatible to be multiplied in some order
#         - The logic is explained [here](https://docs.scipy.org/doc/numpy-1.15.0/user/basics.broadcasting.html#general-broadcasting-rules)

# %% [markdown]
# - We can do any arithmetic on these arrays
#     - Not just multiplication

# %%
array_starting_values + array_multipliers
# Out:
# array([[1.5 , 1.75, 2.  , 2.25],
#        [2.5 , 2.75, 3.  , 3.25],
#        [3.5 , 3.75, 4.  , 4.25]])

# %%
array_starting_values / array_multipliers
# Out:
# array([[2.        , 1.33333333, 1.        , 0.8       ],
#        [4.        , 2.66666667, 2.        , 1.6       ],
#        [6.        , 4.        , 3.        , 2.4       ]])

# %% [markdown]
# - To be clear, let's take another example

# %%
array_1 = np.array([1,2,3])
array_2 = np.array([4,5,6])

# %% [markdown]
# - These arrays are both one dimensional
#     - This is shown below

# %%
array_1.ndim, array_2.ndim
# Out:
# (1, 1)

# %% [markdown]
# - What happens if we add them together?

# %%
array_1 + array_2
# Out:
# array([5, 7, 9])

# %% [markdown]
# - It was just element-wise vector addition
#     - But what if we increase their dimension from 1 to 2?
#         - First, we'll increase the dimension of `array_1`

# %%
array_1 = array_1[np.newaxis, :]

# %%
array_1+array_2
# Out:
# array([[5, 7, 9]])

# %% [markdown]
# - Same as last time
#     - Now, we increase the dimension of `array_2`

# %%
array_2 = array_2[np.newaxis, :]

# %%
array_1+array_2
# Out:
# array([[5, 7, 9]])

# %% [markdown]
# - Again, same thing
#     - Now, what if we pivot `array_2`?
#         - i.e. we transpose it from a row vector to a column vector

# %%
array_2 = np.transpose(array_2)

# %%
array_1+array_2
# Out:
# array([[5, 6, 7],
#        [6, 7, 8],
#        [7, 8, 9]])

# %% [markdown]
# - Now, it has looped through all the row and column values, and added them individually
#     - What if we reverse the order?

# %%
array_2+array_1
# Out:
# array([[5, 6, 7],
#        [6, 7, 8],
#        [7, 8, 9]])

# %% [markdown]
# - The same thing
#     - Again, we see that numpy can perform arithmetic on vectors of different shapes, as long as they can be rearranged into the proper order

# %% [markdown]
# _____
#
# # Using broadcasting to assign curves

# %% [markdown]
# - Let's say we have a lookup table that has the expected number of eggs per week laid by chickens of different breeds

# %%
df_chickens = pd.read_csv('data/chicken1.csv')

# %%
df_chickens.head()
# Out:
#        CHICKEN BREED NAME  Week 1  Week 2  Week 3  Week 4  Week 5  Week 6  \
# 0              Ameraucana       3       6       1       3       9       6
# 1             Ameriflower       5       1      15       1       5      10
# 2                  Ancona       5      10      10      15       1      15
# 3              Andalusian       3       9       3       3       1       1
# 4  Antwerp Belgian Bantam       2       4       2       4       4       6
#
#    Week 7  Week 8  Week 9  Week 10
# 0       9       3       9        1
# 1      15       5      15       10
# 2      15       1       5       15
# 3       3       3       3        1
# 4       1       2       2        4

# %% [markdown]
# - Now let's say we have 10 chickens that are not all the same age
#     - We'll assign their ages and breeds randomly

# %%
np.random.seed(0)
n_chickens = 10
df_coop = pd.DataFrame()
df_coop['Breed'] = np.random.choice(df_chickens['CHICKEN BREED NAME'], size=n_chickens)
df_coop['Week'] = np.random.randint(1,5,size=n_chickens)

# %%
df_coop
# Out:
#                        Breed  Week
# 0                     Marans     3
# 1        Naked Neck (Turken)     2
# 2                       Star     3
# 3       Super Blue Egg Layer     4
# 4       Super Blue Egg Layer     4
# 5                Ayam Cemani     3
# 6                   Cubalaya     1
# 7               Jersey Giant     2
# 8  White Faced Black Spanish     2
# 9              Booted Bantam     2

# %% [markdown]
# - Now, we want to estimate the number of eggs produced by our coop for the next 10 weeks
#     - We can do this by mapping the values in the array

# %% [markdown]
# - But first, we need to add a new column to the table for week 11, with all values equal to zero
#     - It'll come in handy later

# %%
df_chickens['Week 11'] = 0
array_eggs = df_chickens.iloc[:,1:].values

# %%
rows = np.array([list(df_chickens['CHICKEN BREED NAME']).index(x) for x in df_coop['Breed']])

#need to subtract 1 from the line below since the index starts at 0
cols = (df_coop['Week'].values[:,np.newaxis] + np.arange(10))-1

#now, since we made that week 11 column, we can map all values greater than 10 to it
cols = np.minimum(cols, 10)

# %%
df_coop = df_coop.join(pd.DataFrame(array_eggs[rows, cols], columns = ['Eggs laid: {}'.format(x) for x in range(1,11)]))
df_coop
# Out:
#                        Breed  Week  Eggs laid: 1  Eggs laid: 2  Eggs laid: 3  \
# 0                     Marans     3             1             4             1
# 1        Naked Neck (Turken)     2             6             1             5
# 2                       Star     3             1             4             1
# 3       Super Blue Egg Layer     4             9             6             5
# 4       Super Blue Egg Layer     4             9             6             5
# 5                Ayam Cemani     3             1             4             1
# 6                   Cubalaya     1             3             6            10
# 7               Jersey Giant     2             6             1             5
# 8  White Faced Black Spanish     2             6             1             5
# 9              Booted Bantam     2             6             1             5
#
#    Eggs laid: 4  Eggs laid: 5  Eggs laid: 6  Eggs laid: 7  Eggs laid: 8  \
# 0             5            15             2             4             9
# 1             1             5             6             8             3
# 2             5            15             2             4             9
# 3            15            10             6             8             0
# 4            15            10             6             8             0
# 5             5            15             2             4             9
# 6            15             1             4             4             9
# 7             1             5             6             8             3
# 8             1             5             6             8             3
# 9             1             5             6             8             3
#
#    Eggs laid: 9  Eggs laid: 10
# 0             0              0
# 1             3              0
# 2             0              0
# 3             0              0
# 4             0              0
# 5             0              0
# 6             3              4
# 7             3              0
# 8             3              0
# 9             3              0

# %% [markdown]
# - Now, since we have this process down, we can change the `n_chickens` to 100,000

# %%
n_chickens = 100000
df_coop = pd.DataFrame()
df_coop['Breed'] = np.random.choice(df_chickens['CHICKEN BREED NAME'], size=n_chickens)
df_coop['Week'] = np.random.randint(1,5,size=n_chickens)

rows = np.array([list(df_chickens['CHICKEN BREED NAME']).index(x) for x in df_coop['Breed']])

cols = (df_coop['Week'].values[:,np.newaxis] + np.arange(10))-1
cols = np.minimum(cols, 10)

# %%
df_coop = df_coop.join(pd.DataFrame(array_eggs[rows[:,np.newaxis], cols],
                                    columns = ['Eggs laid: {}'.format(x) for x in range(1,11)]))
df_coop
# Out:
#                                 Breed  Week  Eggs laid: 1  Eggs laid: 2  \
# 0                              Polish     1             2             2
# 1                                Java     2             9             1
# 2                              Sultan     2             2             1
# 3                   Olive Egger - MPC     1             3             9
# 4                    Old English Game     3             1             1
# 5                             Buckeye     2             1             9
# 6                              Polish     4             4             4
# 7                           Favaucana     4            10            10
# 8                       Easter Eggers     1             4             1
# 9                Super Blue Egg Layer     3            15            15
# 10                          Wyandotte     3            12            12
# 11                       Rhode Island     4             1            10
# 12                     Russian Orloff     1             2             4
# 13                          Wyandotte     4            12             4
# 14                Naked Neck (Turken)     2             6             1
# 15                            Holland     4             1             9
# 16                             Cochin     3             1             6
# 17                           Langshan     3             6             6
# 18                             Marans     4             9             3
# 19                          Dominique     4             3             3
# 20                     Cuckoo Bluebar     3            10            15
# 21               Super Blue Egg Layer     4            15             1
# 22                   Old English Game     3             1             1
# 23                Leghorn (Non-White)     2             9             3
# 24                             Serama     1             4             8
# 25                         Faverolles     3            12             8
# 26                  Olive Egger - MPC     1             3             9
# 27                             Marans     1             3             6
# 28                           Cubalaya     4             1             4
# 29                          La Fleche     3             6             6
# ...                               ...   ...           ...           ...
# 99970         Appenzeller Spitzhauben     1             3             9
# 99971                         Fayoumi     2             1             6
# 99972                         Phoenix     2             3             1
# 99973                        Araucana     4             9             3
# 99974                     Ameriflower     3            15             1
# 99975              Sicilian Buttercup     2             2             4
# 99976                          Marans     3             1             9
# 99977                  Russian Orloff     2             4             4
# 99978                            Java     1             3             9
# 99979                          Polish     3             2             4
# 99980                          Serama     4             1             8
# 99981                          Legbar     4            12             1
# 99982                       Orpington     4             6             6
# 99983                        Langshan     1             3             9
# 99984                      Australorp     1             5            10
# 99985                   Silkie Bantam     2             9             3
# 99986                         Campine     3             6             9
# 99987                           Malay     3             1             2
# 99988                         Fayoumi     1             2             1
# 99989                      Australorp     1             5            10
# 99990  Belgian Bearded d'Uccle Bantam     1             2             6
# 99991                 Rosecomb Bantam     1             1             1
# 99992                      Crevecoeur     2             1             2
# 99993                       Dominique     2             3             6
# 99994                   Booted Bantam     1             2             4
# 99995                     Ayam Cemani     4             4             6
# 99996                        Yokohama     3             3             1
# 99997               Olive Egger - MPC     1             3             9
# 99998                     Modern Game     4             2             3
# 99999                   Silkie Bantam     4             1             1
#
#        Eggs laid: 3  Eggs laid: 4  Eggs laid: 5  Eggs laid: 6  Eggs laid: 7  \
# 0                 2             4             4             1             2
# 1                 3             6             3             1             6
# 2                 1             1             1             1             2
# 3                 6             6             1             1             9
# 4                 1             1             1             6             6
# 5                 1             3             9             1             3
# 6                 1             2             1             6             2
# 7                 1             5            15             1            10
# 8                12             1            12             4             8
# 9                 1             5            15            10            15
# 10                4            12             8             8             4
# 11               10            10            15            10             5
# 12                4             2             6             4             4
# 13               12             8             8             4             8
# 14                4             6             6             4             2
# 15                3             6             1             6             9
# 16                1             2             6             4             1
# 17                9             9             1             6             6
# 18                3             3             1             3             3
# 19                3             9             9             1             1
# 20                1            10             1            10            15
# 21                5            15            10            15            10
# 22                1             1             1             6             6
# 23                1             9             3             6             9
# 24                8             1             8             1             8
# 25               12             1             8            12             8
# 26                6             6             1             1             9
# 27                1             9             3             3             3
# 28                4             4             8             4             8
# 29                1             3             1             1             6
# ...             ...           ...           ...           ...           ...
# 99970             9             6             9             9             9
# 99971             4             4             2             6             4
# 99972             1             1             2             1             1
# 99973             1             3             6             6             9
# 99974             5            10            15             5            15
# 99975             4             1             6             1             4
# 99976             3             3             3             1             3
# 99977             2             6             4             4             2
# 99978             1             3             6             3             1
# 99979             4             1             2             1             6
# 99980             1             8             1             8             4
# 99981             1            12             1             1             1
# 99982             1             9             1             9             3
# 99983             6             6             9             9             1
# 99984            10             5             1             1            15
# 99985             1             1             3             1             6
# 99986             9             3             9             3             3
# 99987             1             2             2             2             3
# 99988             6             4             4             2             6
# 99989            10             5             1             1            15
# 99990             4             6             1             2             4
# 99991             3             1             1             1             3
# 99992             6             2             1             1             2
# 99993             3             3             3             9             9
# 99994             1             4             1             1             1
# 99995             4             6             2             6             6
# 99996             3             1             3             1             1
# 99997             6             6             1             1             9
# 99998             2             3             2             1             1
# 99999             3             1             6             6             9
#
#        Eggs laid: 8  Eggs laid: 9  Eggs laid: 10
# 0                 1             6              2
# 1                 1             3              0
# 2                 2             2              0
# 3                 9             9              9
# 4                 6             0              0
# 5                 3             6              0
# 6                 0             0              0
# 7                 0             0              0
# 8                12             8              4
# 9                10             0              0
# 10                8             0              0
# 11                0             0              0
# 12                2             6              2
# 13                0             0              0
# 14                4             1              0
# 15                0             0              0
# 16                6             0              0
# 17                9             0              0
# 18                0             0              0
# 19                0             0              0
# 20               15             0              0
# 21                0             0              0
# 22                6             0              0
# 23                9             9              0
# 24                1             8              4
# 25               12             0              0
# 26                9             9              9
# 27                1             3              3
# 28                0             0              0
# 29                9             0              0
# ...             ...           ...            ...
# 99970             1             3              1
# 99971             2             4              0
# 99972             3             1              0
# 99973             0             0              0
# 99974            10             0              0
# 99975             4             1              0
# 99976             3             0              0
# 99977             6             2              0
# 99978             6             1              3
# 99979             2             0              0
# 99980             0             0              0
# 99981             0             0              0
# 99982             0             0              0
# 99983             6             6              9
# 99984            15             1              1
# 99985             6             9              0
# 99986             1             0              0
# 99987             1             0              0
# 99988             4             2              4
# 99989            15             1              1
# 99990             2             4              1
# 99991             3             1              2
# 99992             6             4              0
# 99993             1             1              0
# 99994             2             2              4
# 99995             0             0              0
# 99996             1             0              0
# 99997             9             9              9
# 99998             0             0              0
# 99999             0             0              0
#
# [100000 rows x 12 columns]
